# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("crime.csv")

# %%
data.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2016376978   2016376978521300          5213                       0
# 1       20186000994  20186000994239900          2399                       0
# 2       20166003953  20166003953230500          2305                       0
# 3         201872333    201872333239900          2399                       0
# 4        2017411405   2017411405230300          2303                       0
# 5         201872837    201872837549900          5499                       0
# 6       20186001015  20186001015230400          2304                       0
# 7         201870628    201870628570700          5707                       0
# 8         201870833    201870833540100          5401                       0
# 9       20186001048  20186001048230500          2305                       0
# 10        201872390    201872390357200          3572                       0
# ...

# %%
data['IS_TRAFFIC'].value_counts()
# Out:
# 0    375260
# 1    132183
# Name: IS_TRAFFIC, dtype: int64

# %%
data['IS_CRIME'].value_counts()
# Out:
# 1    375532
# 0    131911
# Name: IS_CRIME, dtype: int64

# %%
data.drop(columns={'GEO_X','GEO_Y'},inplace=True)

# %%
data.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# ...

# %%
data1=data

# %%
cormat=data1.corr()

# %%
cormat
# Out:
#                         INCIDENT_ID  OFFENSE_ID  OFFENSE_CODE  \
# INCIDENT_ID                1.000000    1.000000     -0.130788
# OFFENSE_ID                 1.000000    1.000000     -0.130788
# OFFENSE_CODE              -0.130788   -0.130788      1.000000
# OFFENSE_CODE_EXTENSION     0.030582    0.030582     -0.075584
# GEO_LON                    0.000173    0.000173      0.010430
# GEO_LAT                    0.004627    0.004627     -0.009174
# DISTRICT_ID                0.045774    0.045774     -0.042400
# PRECINCT_ID                0.049675    0.049675     -0.042824
# IS_CRIME                   0.096598    0.096598     -0.572404
# IS_TRAFFIC                -0.096775   -0.096775      0.573220
#
#                         OFFENSE_CODE_EXTENSION   GEO_LON   GEO_LAT  \
# INCIDENT_ID                           0.030582  0.000173  0.004627
# OFFENSE_ID                            0.030582  0.000173  0.004627
# OFFENSE_CODE                         -0.075584  0.010430 -0.009174
# ...

# %%
f,ax = plt.subplots(figsize=(9,8))
sns.heatmap(cormat, ax=ax, cmap="Blues",linewidths=0.1)

# %%
data1.drop(columns={"IS_TRAFFIC"},inplace=True)

# %%
df=data1["DISTRICT_ID"]

# %%
df.nunique()
# Out:
# 7

# %%
ds=data1["PRECINCT_ID"]

# %%
ds.nunique()
# Out:
# 36

# %%
dn=data1["NEIGHBORHOOD_ID"]

# %%
dn.nunique()
# Out:
# 78

# %%
ind=pd.isnull(data1["INCIDENT_ADDRESS"])

# %%
ind.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: INCIDENT_ADDRESS, dtype: bool

# %%
ind.sum()
# Out:
# 49573

# %%
data1.drop(columns={"INCIDENT_ADDRESS"},inplace=True)

# %%
data1['REPORTED_DATE']=pd.to_datetime(data1['REPORTED_DATE'])

# %%
data1['YEAR'] = data1['REPORTED_DATE'].dt.year

# %%
data1['MONTH'] = data1['REPORTED_DATE'].dt.month

# %%
data1['DAY'] = data1['REPORTED_DATE'].dt.day

# %%
data1['HOUR'] = data1['REPORTED_DATE'].dt.hour

# %%
data1
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2016376978   2016376978521300          5213                       0
# 1       20186000994  20186000994239900          2399                       0
# 2       20166003953  20166003953230500          2305                       0
# 3         201872333    201872333239900          2399                       0
# 4        2017411405   2017411405230300          2303                       0
# 5         201872837    201872837549900          5499                       0
# 6       20186001015  20186001015230400          2304                       0
# 7         201870628    201870628570700          5707                       0
# 8         201870833    201870833540100          5401                       0
# 9       20186001048  20186001048230500          2305                       0
# 10        201872390    201872390357200          3572                       0
# ...

# %%
data1["YEAR"].value_counts().plot(kind='bar',color='purple')
plt.title("Crimes each year")
plt.xlabel("year")
plt.ylabel("crime")
# Out:
# Text(0,0.5,'crime')

# %%
data1["MONTH"].value_counts().plot(kind='bar',color='purple')
plt.title("Crimes each month")
plt.xlabel("months")
plt.ylabel("crimes")
# Out:
# Text(0,0.5,'crimes')

# %%
data1["DAY"].value_counts().plot(kind='bar',color='purple')
plt.title("Crimes each day")
plt.xlabel("days")
plt.ylabel("crimes")
# Out:
# Text(0,0.5,'crimes')

# %%
data1["HOUR"].value_counts().plot(kind='bar',color='purple')
plt.title("Crimes each hour")
plt.xlabel("hour")
plt.ylabel("crimes")
# Out:
# Text(0,0.5,'crimes')

# %%
data1['DISTRICT_ID'].value_counts().plot(kind='bar',color='red')
plt.title("Crimes in seperate districts")
plt.xlabel('district')
plt.ylabel('crime')
# Out:
# Text(0,0.5,'crime')

# %%
data['PRECINCT_ID'].value_counts().plot(kind='bar',color='green')
plt.title("Crime in different precinct")
plt.xlabel("precinct")
plt.ylabel("crime")
# Out:
# Text(0,0.5,'crime')

# %%
dv=data1.groupby('DISTRICT_ID')['PRECINCT_ID'].count()

# %%
dv.head()
# Out:
# DISTRICT_ID
# 1     89328
# 2     74393
# 3    112346
# 4     71807
# 5     51714
# Name: PRECINCT_ID, dtype: int64

# %%
dv.plot(kind='bar')

# %%
offense=pd.read_csv('offense_codes.csv')

# %%
offense.head()
# Out:
#    OFFENSE_CODE  OFFENSE_CODE_EXTENSION                 OFFENSE_TYPE_ID  \
# 0          2804                       1      stolen-property-possession
# 1          2804                       2  fraud-possess-financial-device
# 2          2901                       0                damaged-prop-bus
# 3          2902                       0       criminal-mischief-private
# 4          2903                       0        criminal-mischief-public
#
#                        OFFENSE_TYPE_NAME OFFENSE_CATEGORY_ID  \
# 0          Possession of stolen property    all-other-crimes
# 1       Possession of a financial device    all-other-crimes
# 2              Damaged business property     public-disorder
# 3  Criminal mischief to private property     public-disorder
# 4   Criminal mischief to public property     public-disorder
#
#   OFFENSE_CATEGORY_NAME  IS_CRIME  IS_TRAFFIC
# 0      All Other Crimes         1           0
# 1      All Other Crimes         1           0
# ...

# %%
offense1=offense

# %%
offense1.corr()
# Out:
#                         OFFENSE_CODE  OFFENSE_CODE_EXTENSION  IS_CRIME  \
# OFFENSE_CODE                1.000000                0.092544 -0.165622
# OFFENSE_CODE_EXTENSION      0.092544                1.000000 -0.080470
# IS_CRIME                   -0.165622               -0.080470  1.000000
# IS_TRAFFIC                  0.192404                0.050998 -0.863065
#
#                         IS_TRAFFIC
# OFFENSE_CODE              0.192404
# OFFENSE_CODE_EXTENSION    0.050998
# IS_CRIME                 -0.863065
# IS_TRAFFIC                1.000000

# %%
offense1.drop(columns={'IS_TRAFFIC'},inplace=True)

# %%
offense1['OFFENSE_CATEGORY_ID'].value_counts()
# Out:
# all-other-crimes                107
# drug-alcohol                     30
# white-collar-crime               29
# public-disorder                  27
# larceny                          15
# other-crimes-against-persons     14
# aggravated-assault               13
# sexual-assault                   13
# robbery                          13
# burglary                         11
# murder                            9
# traffic-accident                  6
# arson                             5
# auto-theft                        4
# theft-from-motor-vehicle          3
# Name: OFFENSE_CATEGORY_ID, dtype: int64

# %%
offense1['OFFENSE_CATEGORY_ID'].value_counts().plot(kind='bar',color='blue')
plt.xlabel('offense type')
plt.ylabel('crime')
plt.title('crime types')
# Out:
# Text(0.5,1,'crime types')

# %%
offense1.drop(columns={"OFFENSE_CATEGORY_NAME"},inplace=True)
