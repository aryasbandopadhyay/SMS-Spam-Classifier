# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("crime.csv")

# %%
data.head(10)
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
# 5    201872837    201872837549900          5499                       0
# 6  20186001015  20186001015230400          2304                       0
# 7    201870628    201870628570700          5707                       0
# 8    201870833    201870833540100          5401                       0
# 9  20186001048  20186001048230500          2305                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# ...

# %%
data["OFFENSE_CODE"].nunique()
# Out:
# 156

# %%
data["INCIDENT_ID"].nunique()
# Out:
# 469041

# %%
data["OFFENSE_CODE_EXTENSION"].nunique()
# Out:
# 6

# %%
data["OFFENSE_TYPE_ID"].nunique()
# Out:
# 201

# %%
data["OFFENSE_ID"].nunique()
# Out:
# 507443

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507443 entries, 0 to 507442
# Data columns (total 19 columns):
# INCIDENT_ID               507443 non-null int64
# OFFENSE_ID                507443 non-null int64
# OFFENSE_CODE              507443 non-null int64
# OFFENSE_CODE_EXTENSION    507443 non-null int64
# OFFENSE_TYPE_ID           507443 non-null object
# OFFENSE_CATEGORY_ID       507443 non-null object
# FIRST_OCCURRENCE_DATE     507443 non-null object
# LAST_OCCURRENCE_DATE      160658 non-null object
# REPORTED_DATE             507443 non-null object
# INCIDENT_ADDRESS          457870 non-null object
# GEO_X                     503263 non-null float64
# GEO_Y                     503263 non-null float64
# GEO_LON                   503263 non-null float64
# GEO_LAT                   503263 non-null float64
# DISTRICT_ID               507443 non-null int64
# PRECINCT_ID               507443 non-null int64
# NEIGHBORHOOD_ID           507443 non-null object
# ...

# %%
data['IS_TRAFFIC'].value_counts()
# Out:
# 0    375260
# 1    132183
# Name: IS_TRAFFIC, dtype: int64

# %%
data['IS_CRIME'].value_counts()
# Out:
# 1    375532
# 0    131911
# Name: IS_CRIME, dtype: int64

# %%
data.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# ...

# %%
data1=data

# %%
cormat=data1.corr()

# %%
cormat
# Out:
#                         INCIDENT_ID  OFFENSE_ID  OFFENSE_CODE  \
# INCIDENT_ID                1.000000    1.000000     -0.130788
# OFFENSE_ID                 1.000000    1.000000     -0.130788
# OFFENSE_CODE              -0.130788   -0.130788      1.000000
# OFFENSE_CODE_EXTENSION     0.030582    0.030582     -0.075584
# GEO_X                     -0.000412   -0.000412      0.010545
# GEO_Y                      0.000819    0.000819      0.013738
# GEO_LON                    0.000173    0.000173      0.010430
# GEO_LAT                    0.004627    0.004627     -0.009174
# DISTRICT_ID                0.045774    0.045774     -0.042400
# PRECINCT_ID                0.049675    0.049675     -0.042824
# IS_CRIME                   0.096598    0.096598     -0.572404
# IS_TRAFFIC                -0.096775   -0.096775      0.573220
#
#                         OFFENSE_CODE_EXTENSION     GEO_X     GEO_Y   GEO_LON  \
# INCIDENT_ID                           0.030582 -0.000412  0.000819  0.000173
# ...

# %%
f,ax = plt.subplots(figsize=(9,8))
sns.heatmap(cormat, ax=ax, cmap="Blues",linewidths=0.1)

# %%
data1.drop(columns={"IS_TRAFFIC"},inplace=True)

# %%
df=data1["DISTRICT_ID"]

# %%
df.nunique()
# Out:
# 7

# %%
ds=data1["PRECINCT_ID"]

# %%
ds.nunique()
# Out:
# 36

# %%
dn=data1["NEIGHBORHOOD_ID"]

# %%
dn.nunique()
# Out:
# 78

# %%
ind=pd.isnull(data1["INCIDENT_ADDRESS"])

# %%
ind.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: INCIDENT_ADDRESS, dtype: bool

# %%
ind.sum()
# Out:
# 49573

# %%
data1.drop(columns={"INCIDENT_ADDRESS"},inplace=True)

# %%
data1['FIRST_OCCURRENCE_DATE']=pd.to_datetime(data1['FIRST_OCCURRENCE_DATE'])

# %%
data1['YEAR'] = data1['FIRST_OCCURRENCE_DATE'].dt.year

# %%
data1['MONTH'] = data1['FIRST_OCCURRENCE_DATE'].dt.month

# %%
data1['DAY'] = data1['FIRST_OCCURRENCE_DATE'].dt.day

# %%
data1['HOUR'] = data1['FIRST_OCCURRENCE_DATE'].dt.hour

# %%
data1
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2016376978   2016376978521300          5213                       0
# 1       20186000994  20186000994239900          2399                       0
# 2       20166003953  20166003953230500          2305                       0
# 3         201872333    201872333239900          2399                       0
# 4        2017411405   2017411405230300          2303                       0
# 5         201872837    201872837549900          5499                       0
# 6       20186001015  20186001015230400          2304                       0
# 7         201870628    201870628570700          5707                       0
# 8         201870833    201870833540100          5401                       0
# 9       20186001048  20186001048230500          2305                       0
# 10        201872390    201872390357200          3572                       0
# ...

# %%
a_list=data1["YEAR"].tolist()

# %%
a=pd.DataFrame()

# %%
a['YEAR']=a_list

# %%
fig, ax=plt.subplots(figsize=(7,7))
sns.countplot(a['YEAR'],palette='BuGn_r')

# %%
b_list=data1["MONTH"].tolist()
b=pd.DataFrame()
b["MONTH"]=b_list

# %%
fig, ax=plt.subplots(figsize=(7,7))
sns.countplot(y=b["MONTH"],palette='muted')

# %%
c_list=data1["DAY"].tolist()
c=pd.DataFrame()
c["DAY"]=c_list

fig, ax=plt.subplots(figsize=(10,10))
sns.countplot(y=c["DAY"],palette='coolwarm')

# %%
d_list=data1["HOUR"].tolist()
d=pd.DataFrame()
d["HOUR"]=d_list

fig, ax=plt.subplots(figsize=(6,6))
sns.countplot(y=d["HOUR"],color='y')

# %%
e_list=data1["DISTRICT_ID"].tolist()
e=pd.DataFrame()
e["DISTRICT_ID"]=e_list
fig,ax=plt.subplots(figsize=(6,6))
sns.countplot(e["DISTRICT_ID"],palette='Blues_d')

# %%
f_list=data1["PRECINCT_ID"].tolist()
f=pd.DataFrame()
f["PRECINCT_ID"]=f_list
fig,ax=plt.subplots(figsize=(20,20))
sns.countplot(y=f["PRECINCT_ID"],palette='husl')

# %%
dv=data1.groupby('DISTRICT_ID')['PRECINCT_ID'].count().reset_index()

# %%
dv
# Out:
#    DISTRICT_ID  PRECINCT_ID
# 0            1        89328
# 1            2        74393
# 2            3       112346
# 3            4        71807
# 4            5        51714
# 5            6       101977
# 6            7         5878

# %%
g_list=dv["DISTRICT_ID"].tolist()
g=pd.DataFrame()
g["DISTRICT_ID"]=g_list
fig,ax=plt.subplots(figsize=(7,7))
sns.lineplot(data=dv)

# %%
from matplotlib import ggplot
from ggplot import *
ggplot(aes(x='NEIGHBORHOOD_ID',y='IS_CRIME'),data=data1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-76-901ca76aa774> in <module>
# ----> 1 from matplotlib import ggplot
#       2 from ggplot import *
#       3 ggplot(aes(x='NEIGHBORHOOD_ID',y='IS_CRIME'),data=data1)
#
# ImportError: cannot import name 'ggplot' from 'matplotlib' (C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py)

# %%
r_list=data1["NEIGHBORHOOD_ID"].tolist()
r=pd.DataFrame()
r["NEIGHBORHOOD_ID"]=r_list
fig,ax=plt.subplots(figsize=(8,8))
sns.countplot(y=["NEIGHBORHOOD_ID"],palette='muted')

# %%
offense=pd.read_csv('offense_codes.csv')

# %%
offense.head()

# %%
offense1=offense

# %%
offense1.corr()

# %%
offense1.drop(columns={'IS_TRAFFIC'},inplace=True)

# %%
offense1['OFFENSE_CATEGORY_ID'].value_counts()

# %%
offense1['OFFENSE_CATEGORY_ID'].value_counts().plot(kind='bar',color='blue')
plt.xlabel('offense type')
plt.ylabel('crime')
plt.title('crime types')

# %%
offense1.drop(columns={"OFFENSE_CATEGORY_NAME"},inplace=True)
